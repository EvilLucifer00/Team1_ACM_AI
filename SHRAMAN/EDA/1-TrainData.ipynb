# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading data
try:
    data_path = '../data/train.csv'
    print(f"Attempting to load data from: {data_path}")

    # --- Load the data ---
    df = pd.read_csv(data_path)

    # --- ESSENTIAL: Perform initial checks ---
    print("\n✅ Data loaded successfully!")
    print(f"Shape of the data (rows, columns): {df.shape}")

    print("\n--- First 5 Rows ---")
    display(df.head())

    print("\n--- Data Info (Column Names, Non-Null Counts, Data Types) ---")
    df.info()

except FileNotFoundError:
    print(f"❌ Error: The file was not found at the path: {data_path}")
    print("Please check that the file exists and the path is correct.")
except Exception as e:
    print(f"❌ An unexpected error occurred: {e}")
# Out:
# Attempting to load data from: ../data/train.csv
#
# ✅ Data loaded successfully!
# Shape of the data (rows, columns): (50000, 4)
#
# --- First 5 Rows ---
#    sample_id                                    catalog_content  \
# 0     158784  Item Name: Log Cabin Sugar Free Syrup, 24 FL O...
# 1       4095  Item Name: Raspberry Ginseng Oolong Tea (50 te...
# 2     172021  Item Name: Walden Farms Honey Dijon Dressing -...
# 3     268276  Item Name: Vlasic Ovals Hamburger Dill Pickle ...
# 4     154791  Item Name: Amoretti Premium Syrup, Grand Orang...
#
#                                           image_link   price
# 0  https://m.media-amazon.com/images/I/71QD2OFXqD...  12.195
# 1  https://m.media-amazon.com/images/I/813OiT8mdJ...  38.540
# 2  https://m.media-amazon.com/images/I/71HGx42QmU...  17.860
# 3  https://m.media-amazon.com/images/I/71AbnhXOTA...   2.940
# 4  https://m.media-amazon.com/images/I/61c+aTE6TY...  25.990
# --- Data Info (Column Names, Non-Null Counts, Data Types) ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sample_id        50000 non-null  int64
#  1   catalog_content  50000 non-null  object
#  2   image_link       50000 non-null  object
#  3   price            50000 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.5+ MB

# %%
df_cleaned=df.copy()
df_cleaned
# Out:
#        sample_id                                    catalog_content  \
# 0         158784  Item Name: Log Cabin Sugar Free Syrup, 24 FL O...
# 1           4095  Item Name: Raspberry Ginseng Oolong Tea (50 te...
# 2         172021  Item Name: Walden Farms Honey Dijon Dressing -...
# 3         268276  Item Name: Vlasic Ovals Hamburger Dill Pickle ...
# 4         154791  Item Name: Amoretti Premium Syrup, Grand Orang...
# ...          ...                                                ...
# 49995      43460  Item Name: Java Monster Coffee + Energy Drink,...
# 49996      96214  Item Name: Gits Upma Mix 7 Oz by Gits\nValue: ...
# 49997     196377  Item Name: Black Cohosh and Dong Quai Combinat...
# 49998     291807  Item Name: WOODSTOCK FARMS Organic Wheat Berri...
# 49999     290187  Item Name: Wyler's Light Singles To Go Powder ...
#
#                                               image_link    price
# 0      https://m.media-amazon.com/images/I/71QD2OFXqD...   12.195
# 1      https://m.media-amazon.com/images/I/813OiT8mdJ...   38.540
# 2      https://m.media-amazon.com/images/I/71HGx42QmU...   17.860
# 3      https://m.media-amazon.com/images/I/71AbnhXOTA...    2.940
# 4      https://m.media-amazon.com/images/I/61c+aTE6TY...   25.990
# ...                                                  ...      ...
# 49995  https://m.media-amazon.com/images/I/51jGEnLv8-...   29.520
# 49996  https://m.media-amazon.com/images/I/41OmUcWbNB...    7.990
# 49997  https://m.media-amazon.com/images/I/811HtPUwUw...   48.560
# 49998  https://m.media-amazon.com/images/I/61w1+b+Unj...  103.240
# 49999  https://m.media-amazon.com/images/I/912iQlVtyD...   18.590
#
# [50000 rows x 4 columns]

# %%
df_cleaned.isnull().sum()
# Out:
# sample_id          0
# catalog_content    0
# image_link         0
# price              0
# dtype: int64

# %%
df_cleaned.describe()
# Out:
#            sample_id         price
# count   50000.000000  50000.000000
# mean   149631.398980     23.605707
# std     86443.518122     34.401896
# min         4.000000      0.300000
# 25%     74010.750000      6.750000
# 50%    150016.500000     13.990000
# 75%    224629.000000     28.490000
# max    299428.000000   2796.000000

# %%
df_cleaned.shape
# Out:
# (50000, 4)

# %%
df['image_link']=df['image_link'].fillna('no_image')

# %%
## handling duplicates
df_cleaned = df_cleaned.drop_duplicates()

# %%
df_cleaned.shape
# Out:
# (50000, 4)

# %%
df_cleaned['catalog_content'] = df_cleaned['catalog_content'].str.strip().str.title()

# %%
# IMPROVED: This regex captures the first word and an optional second word.
df_cleaned['brand'] = df_cleaned['catalog_content'].str.extract(r'^(\w+(?:\s+\w+)?)', expand=False)

# %%
df_cleaned.head()
# Out:
#    sample_id                                    catalog_content  \
# 0     158784  Item Name: Log Cabin Sugar Free Syrup, 24 Fl O...
# 1       4095  Item Name: Raspberry Ginseng Oolong Tea (50 Te...
# 2     172021  Item Name: Walden Farms Honey Dijon Dressing -...
# 3     268276  Item Name: Vlasic Ovals Hamburger Dill Pickle ...
# 4     154791  Item Name: Amoretti Premium Syrup, Grand Orang...
#
#                                           image_link   price      brand
# 0  https://m.media-amazon.com/images/I/71QD2OFXqD...  12.195  Item Name
# 1  https://m.media-amazon.com/images/I/813OiT8mdJ...  38.540  Item Name
# 2  https://m.media-amazon.com/images/I/71HGx42QmU...  17.860  Item Name
# 3  https://m.media-amazon.com/images/I/71AbnhXOTA...   2.940  Item Name
# 4  https://m.media-amazon.com/images/I/61c+aTE6TY...  25.990  Item Name

# %%
df_cleaned['pack_size'] = (
    pd.to_numeric(df_cleaned['catalog_content'].str.extract(r'Pack of (\d+)', expand=False), errors='coerce')
    .fillna(1)
    .astype(int)
)

# %%
df_cleaned
# Out:
#        sample_id                                    catalog_content  \
# 0         158784  Item Name: Log Cabin Sugar Free Syrup, 24 Fl O...
# 1           4095  Item Name: Raspberry Ginseng Oolong Tea (50 Te...
# 2         172021  Item Name: Walden Farms Honey Dijon Dressing -...
# 3         268276  Item Name: Vlasic Ovals Hamburger Dill Pickle ...
# 4         154791  Item Name: Amoretti Premium Syrup, Grand Orang...
# ...          ...                                                ...
# 49995      43460  Item Name: Java Monster Coffee + Energy Drink,...
# 49996      96214  Item Name: Gits Upma Mix 7 Oz By Gits\nValue: ...
# 49997     196377  Item Name: Black Cohosh And Dong Quai Combinat...
# 49998     291807  Item Name: Woodstock Farms Organic Wheat Berri...
# 49999     290187  Item Name: Wyler'S Light Singles To Go Powder ...
#
#                                               image_link    price      brand  \
# 0      https://m.media-amazon.com/images/I/71QD2OFXqD...   12.195  Item Name
# 1      https://m.media-amazon.com/images/I/813OiT8mdJ...   38.540  Item Name
# 2      https://m.media-amazon.com/images/I/71HGx42QmU...   17.860  Item Name
# 3      https://m.media-amazon.com/images/I/71AbnhXOTA...    2.940  Item Name
# 4      https://m.media-amazon.com/images/I/61c+aTE6TY...   25.990  Item Name
# ...                                                  ...      ...        ...
# 49995  https://m.media-amazon.com/images/I/51jGEnLv8-...   29.520  Item Name
# 49996  https://m.media-amazon.com/images/I/41OmUcWbNB...    7.990  Item Name
# 49997  https://m.media-amazon.com/images/I/811HtPUwUw...   48.560  Item Name
# 49998  https://m.media-amazon.com/images/I/61w1+b+Unj...  103.240  Item Name
# 49999  https://m.media-amazon.com/images/I/912iQlVtyD...   18.590  Item Name
#
#        pack_size
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 49995          1
# 49996          1
# 49997          1
# 49998          1
# 49999          1
#
# [50000 rows x 6 columns]

# %%
import re
df_cleaned['product_size'] = (
    df_cleaned['catalog_content']
    .str.extract(r'((\d+\.?\d*)\s*(Fl\.?\s*Oz|Oz|Gallon|L|ml|g))', re.IGNORECASE)[0]
)

# %%
df_cleaned
# Out:
#        sample_id                                    catalog_content  \
# 0         158784  Item Name: Log Cabin Sugar Free Syrup, 24 Fl O...
# 1           4095  Item Name: Raspberry Ginseng Oolong Tea (50 Te...
# 2         172021  Item Name: Walden Farms Honey Dijon Dressing -...
# 3         268276  Item Name: Vlasic Ovals Hamburger Dill Pickle ...
# 4         154791  Item Name: Amoretti Premium Syrup, Grand Orang...
# ...          ...                                                ...
# 49995      43460  Item Name: Java Monster Coffee + Energy Drink,...
# 49996      96214  Item Name: Gits Upma Mix 7 Oz By Gits\nValue: ...
# 49997     196377  Item Name: Black Cohosh And Dong Quai Combinat...
# 49998     291807  Item Name: Woodstock Farms Organic Wheat Berri...
# 49999     290187  Item Name: Wyler'S Light Singles To Go Powder ...
#
#                                               image_link    price      brand  \
# 0      https://m.media-amazon.com/images/I/71QD2OFXqD...   12.195  Item Name
# 1      https://m.media-amazon.com/images/I/813OiT8mdJ...   38.540  Item Name
# 2      https://m.media-amazon.com/images/I/71HGx42QmU...   17.860  Item Name
# 3      https://m.media-amazon.com/images/I/71AbnhXOTA...    2.940  Item Name
# 4      https://m.media-amazon.com/images/I/61c+aTE6TY...   25.990  Item Name
# ...                                                  ...      ...        ...
# 49995  https://m.media-amazon.com/images/I/51jGEnLv8-...   29.520  Item Name
# 49996  https://m.media-amazon.com/images/I/41OmUcWbNB...    7.990  Item Name
# 49997  https://m.media-amazon.com/images/I/811HtPUwUw...   48.560  Item Name
# 49998  https://m.media-amazon.com/images/I/61w1+b+Unj...  103.240  Item Name
# 49999  https://m.media-amazon.com/images/I/912iQlVtyD...   18.590  Item Name
#
#        pack_size product_size
# 0              1     24 Fl Oz
# 1              1          1 L
# 2              1        12 Oz
# 3              1     16 Fl Oz
# 4              1          NaN
# ...          ...          ...
# 49995          1          NaN
# 49996          1         7 Oz
# 49997          1         4 Oz
# 49998          1         50 L
# 49999          1          NaN
#
# [50000 rows x 7 columns]
